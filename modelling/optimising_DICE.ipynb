# %% [markdown]
# ## Optimising DICE

# %%
using Pkg;
Pkg.activate(".") # activate the environment in the "modelling" folder
Pkg.instantiate() # install the packages in the environment
# Out:
#   Activating project at `c:\Users\marai\OneDrive\Dokumente\Master\Masterarbeit\adv_env_econ_24\modelling`

# %% [markdown]
# ### Replacing MimiDICE2016R2 with OptMimiDICE2016R2
#
# OptMimiDICE2016R2 is a fork of MimiDICE2016R2 that includes an optimisation routine. Because they share the same package ID, we need to remove MimiDICE2016R2 before adding OptMimiDICE2016R2.
# You need to do this only once. After that, you can comment out the following lines.

# %%
Pkg.rm("MimiDICE2016R2")
Pkg.add(url="https://github.com/felixschaumann/OptMimiDICE2016R2.jl")
# Out:
#     Updating `C:\Users\marai\OneDrive\Dokumente\Master\Masterarbeit\adv_env_econ_24\modelling\Project.toml`
#   [f1883be1] - MimiDICE2016R2 v0.1.1-DEV `https://github.com/anthofflab/MimiDICE2016R2.jl#master`
#     Updating `C:\Users\marai\OneDrive\Dokumente\Master\Masterarbeit\adv_env_econ_24\modelling\Manifest.toml`
#   [8f5d6c58] - EzXML v1.2.0
#   [f1883be1] - MimiDICE2016R2 v0.1.1-DEV `https://github.com/anthofflab/MimiDICE2016R2.jl#master`
#   [fdbf4ff8] - XLSX v0.7.10
#   [a5390f91] - ZipFile v0.9.4
#     Updating git-repo `https://github.com/felixschaumann/OptMimiDICE2016R2.jl`
#    Resolving package versions...
#     Updating `C:\Users\marai\OneDrive\Dokumente\Master\Masterarbeit\adv_env_econ_24\modelling\Project.toml`
#   [f1883be1] + OptMimiDICE2016R2 v0.1.1-DEV `https://github.com/felixschaumann/OptMimiDICE2016R2.jl#main`
#     Updating `C:\Users\marai\OneDrive\Dokumente\Master\Masterarbeit\adv_env_econ_24\modelling\Manifest.toml`
#   [a4c015fc] + ANSIColoredPrinters v0.0.1
#   [1520ce14] + AbstractTrees v0.4.5
#   [8f4d0f93] + Conda v1.10.2
#   [e30172f5] + Documenter v1.5.0
#   [634d3b9d] + DrWatson v2.15.0
#   [8f5d6c58] + EzXML v1.2.0
#   [d7ba0133] + Git v1.3.1
#   [b5f81e59] + IOCapture v0.2.5
#   [033835bb] + JLD2 v0.4.51
#   [0e77f7df] + LazilyInitializedFields v1.2.2
#   [d0879d2d] + MarkdownAST v0.1.2
#   [76087f3c] + NLopt v1.0.2
#   [f1883be1] + OptMimiDICE2016R2 v0.1.1-DEV `https://github.com/felixschaumann/OptMimiDICE2016R2.jl#main`
#   [438e738f] + PyCall v1.96.4
#   [d330b81b] + PyPlot v2.11.5
#   [2792f1a3] + RegistryInstances v0.1.0
#   [3a884ed6] + UnPack v1.0.2
#   [81def892] + VersionParsing v1.3.0
#   [fdbf4ff8] + XLSX v0.10.1
#   [a5390f91] + ZipFile v0.10.1
#   [f8c6e375] + Git_jll v2.44.0+2
#   [079eb43e] + NLopt_jll v2.7.1+0
# Precompiling project...
#   ✗ PyCall
#   ✗ PyPlot
#   ✓ OptMimiDICE2016R2
#   1 dependency successfully precompiled in 30 seconds. 282 already precompiled.

# %% [markdown]
# ### Running and optimising DICE

# %%
using Mimi
using OptMimiDICE2016R2

# %%
m_opt = OptMimiDICE2016R2.get_model()
run(m_opt)

# %%
@time m_opt, diagn = OptMimiDICE2016R2.optimise_model(m_opt)
# Out:
# (m = Mimi.Model
#   Module: Mimi
#   Components:
#     ComponentId(OptMimiDICE2016R2.totalfactorproductivity)
#     ComponentId(OptMimiDICE2016R2.grosseconomy)
#     ComponentId(OptMimiDICE2016R2.emissions)
#     ComponentId(OptMimiDICE2016R2.co2cycle)
#     ComponentId(OptMimiDICE2016R2.radiativeforcing)
#     ComponentId(OptMimiDICE2016R2.climatedynamics)
#     ComponentId(OptMimiDICE2016R2.damages)
#     ComponentId(OptMimiDICE2016R2.neteconomy)
#     ComponentId(OptMimiDICE2016R2.welfare)
#   Dimensions:
#     time => [2015, 2020, 2025, 2030, 2035, 2040, 2045, 2050, 2055, 2060, 2065, 2070, 2075, 2080, 2085, 2090, 2095, 2100, 2105, 2110, 2115, 2120, 2125, 2130, 2135, 2140, 2145, 2150, 2155, 2160, 2165, 2170, 2175, 2180, 2185, 2190, 2195, 2200, 2205, 2210, 2215, 2220, 2225, 2230, 2235, 2240, 2245, 2250, 2255, 2260, 2265, 2270, 2275, 2280, 2285, 2290, 2295, 2300, 2305, 2310, 2315, 2320, 2325, 2330, 2335, 2340, 2345, 2350, 2355, 2360, 2365, 2370, 2375, 2380, 2385, 2390, 2395, 2400, 2405, 2410, 2415, 2420, 2425, 2430, 2435, 2440, 2445, 2450, 2455, 2460, 2465, 2470, 2475, 2480, 2485, 2490, 2495, 2500, 2505, 2510]
#   Internal Connections:
#     Mimi.InternalParameterConnection
#   src_comp_path: ComponentPath(Symbol("##ModelDef#225"), :totalfactorproductivity)
#   src_var_name: :AL
#   dst_comp_path: ComponentPath(Symbol("##ModelDef#225"), :grosseconomy)
#   dst_par_name: :AL
#   ignoreunits: false
#   backup: nothing
#   backup_offset: nothing
#     Mimi.InternalParameterConnection
#   src_comp_path: ComponentPath(Symbol("##ModelDef#225"), :neteconomy)
#   src_var_name: :I
#   dst_comp_path: ComponentPath(Symbol("##ModelDef#225"), :grosseconomy)
#   dst_par_name: :I
#   ignoreunits: false
#   backup: nothing
#   backup_offset: nothing
#     Mimi.InternalParameterConnection
#   src_comp_path: ComponentPath(Symbol("##ModelDef#225"), :grosseconomy)
#   src_var_name: :YGROSS
#   dst_comp_path: ComponentPath(Symbol("##ModelDef#225"), :emissions)
#   dst_par_name: :YGROSS
#   ignoreunits: false
#   backup: nothing
#   backup_offset: nothing
#     Mimi.InternalParameterConnection
#   src_comp_path: ComponentPath(Symbol("##ModelDef#225"), :emissions)
#   src_var_name: :E
#   dst_comp_path: ComponentPath(Symbol("##ModelDef#225"), :co2cycle)
#   dst_par_name: :E
#   ignoreunits: false
#   backup: nothing
#   backup_offset: nothing
#     Mimi.InternalParameterConnection
#   src_comp_path: ComponentPath(Symbol("##ModelDef#225"), :co2cycle)
#   src_var_name: :MAT
#   dst_comp_path: ComponentPath(Symbol("##ModelDef#225"), :radiativeforcing)
#   dst_par_name: :MAT
#   ignoreunits: false
#   backup: nothing
#   backup_offset: nothing
#     Mimi.InternalParameterConnection
#   src_comp_path: ComponentPath(Symbol("##ModelDef#225"), :radiativeforcing)
#   src_var_name: :FORC
#   dst_comp_path: ComponentPath(Symbol("##ModelDef#225"), :climatedynamics)
#   dst_par_name: :FORC
#   ignoreunits: false
#   backup: nothing
#   backup_offset: nothing
#     Mimi.InternalParameterConnection
#   src_comp_path: ComponentPath(Symbol("##ModelDef#225"), :climatedynamics)
#   src_var_name: :TATM
#   dst_comp_path: ComponentPath(Symbol("##ModelDef#225"), :damages)
#   dst_par_name: :TATM
#   ignoreunits: false
#   backup: nothing
#   backup_offset: nothing
#     Mimi.InternalParameterConnection
#   src_comp_path: ComponentPath(Symbol("##ModelDef#225"), :grosseconomy)
#   src_var_name: :YGROSS
#   dst_comp_path: ComponentPath(Symbol("##ModelDef#225"), :damages)
#   dst_par_name: :YGROSS
#   ignoreunits: false
#   backup: nothing
#   backup_offset: nothing
#     Mimi.InternalParameterConnection
#   src_comp_path: ComponentPath(Symbol("##ModelDef#225"), :grosseconomy)
#   src_var_name: :YGROSS
#   dst_comp_path: ComponentPath(Symbol("##ModelDef#225"), :neteconomy)
#   dst_par_name: :YGROSS
#   ignoreunits: false
#   backup: nothing
#   backup_offset: nothing
#     Mimi.InternalParameterConnection
#   src_comp_path: ComponentPath(Symbol("##ModelDef#225"), :damages)
#   src_var_name: :DAMAGES
#   dst_comp_path: ComponentPath(Symbol("##ModelDef#225"), :neteconomy)
#   dst_par_name: :DAMAGES
#   ignoreunits: false
#   backup: nothing
#   backup_offset: nothing
#     Mimi.InternalParameterConnection
#   src_comp_path: ComponentPath(Symbol("##ModelDef#225"), :emissions)
#   src_var_name: :SIGMA
#   dst_comp_path: ComponentPath(Symbol("##ModelDef#225"), :neteconomy)
#   dst_par_name: :SIGMA
#   ignoreunits: false
#   backup: nothing
#   backup_offset: nothing
#     Mimi.InternalParameterConnection
#   src_comp_path: ComponentPath(Symbol("##ModelDef#225"), :neteconomy)
#   src_var_name: :CPC
#   dst_comp_path: ComponentPath(Symbol("##ModelDef#225"), :welfare)
#   dst_par_name: :CPC
#   ignoreunits: false
#   backup: nothing
#   backup_offset: nothing
#   External Connections:
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :totalfactorproductivity)
#   param_name: :a0
#   model_param_name: Symbol("##226")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :totalfactorproductivity)
#   param_name: :ga0
#   model_param_name: Symbol("##227")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :totalfactorproductivity)
#   param_name: :dela
#   model_param_name: Symbol("##228")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :grosseconomy)
#   param_name: :dk
#   model_param_name: Symbol("##232")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :grosseconomy)
#   param_name: :gama
#   model_param_name: Symbol("##233")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :grosseconomy)
#   param_name: :k0
#   model_param_name: Symbol("##234")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :emissions)
#   param_name: :gsigma1
#   model_param_name: Symbol("##235")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :emissions)
#   param_name: :dsig
#   model_param_name: Symbol("##236")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :emissions)
#   param_name: :eland0
#   model_param_name: Symbol("##237")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :emissions)
#   param_name: :deland
#   model_param_name: Symbol("##238")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :emissions)
#   param_name: :e0
#   model_param_name: Symbol("##239")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :emissions)
#   param_name: :cca0
#   model_param_name: Symbol("##242")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :emissions)
#   param_name: :cumetree0
#   model_param_name: Symbol("##243")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :co2cycle)
#   param_name: :b12
#   model_param_name: Symbol("##244")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :co2cycle)
#   param_name: :b23
#   model_param_name: Symbol("##245")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :co2cycle)
#   param_name: :mateq
#   model_param_name: Symbol("##246")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :co2cycle)
#   param_name: :mueq
#   model_param_name: Symbol("##247")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :co2cycle)
#   param_name: :mleq
#   model_param_name: Symbol("##248")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :co2cycle)
#   param_name: :mat0
#   model_param_name: Symbol("##250")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :co2cycle)
#   param_name: :ml0
#   model_param_name: Symbol("##251")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :co2cycle)
#   param_name: :mu0
#   model_param_name: Symbol("##252")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :radiativeforcing)
#   param_name: :eqmat
#   model_param_name: Symbol("##254")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :radiativeforcing)
#   param_name: :fex0
#   model_param_name: Symbol("##256")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :radiativeforcing)
#   param_name: :fex1
#   model_param_name: Symbol("##257")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :climatedynamics)
#   param_name: :t2xco2
#   model_param_name: Symbol("##260")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :climatedynamics)
#   param_name: :tatm0
#   model_param_name: Symbol("##261")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :climatedynamics)
#   param_name: :tocean0
#   model_param_name: Symbol("##262")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :climatedynamics)
#   param_name: :c1
#   model_param_name: Symbol("##263")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :climatedynamics)
#   param_name: :c3
#   model_param_name: Symbol("##264")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :climatedynamics)
#   param_name: :c4
#   model_param_name: Symbol("##265")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :damages)
#   param_name: :a1
#   model_param_name: Symbol("##268")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :damages)
#   param_name: :a2
#   model_param_name: Symbol("##269")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :damages)
#   param_name: :a3
#   model_param_name: Symbol("##270")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :neteconomy)
#   param_name: :S
#   model_param_name: Symbol("##275")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :neteconomy)
#   param_name: :expcost2
#   model_param_name: Symbol("##277")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :neteconomy)
#   param_name: :pback
#   model_param_name: Symbol("##278")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :neteconomy)
#   param_name: :gback
#   model_param_name: Symbol("##279")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :welfare)
#   param_name: :rr
#   model_param_name: Symbol("##282")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :welfare)
#   param_name: :elasmu
#   model_param_name: Symbol("##283")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :welfare)
#   param_name: :scale1
#   model_param_name: Symbol("##284")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :welfare)
#   param_name: :scale2
#   model_param_name: Symbol("##285")
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :climatedynamics)
#   param_name: :fco22x
#   model_param_name: :fco22x
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :radiativeforcing)
#   param_name: :fco22x
#   model_param_name: :fco22x
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :grosseconomy)
#   param_name: :l
#   model_param_name: :l
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :neteconomy)
#   param_name: :l
#   model_param_name: :l
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :welfare)
#   param_name: :l
#   model_param_name: :l
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :neteconomy)
#   param_name: :MIU
#   model_param_name: :MIU
#     Mimi.ExternalParameterConnection
#   comp_path: ComponentPath(Symbol("##ModelDef#225"), :emissions)
#   param_name: :MIU
#   model_param_name: :MIU
#   Backups: Symbol[]
#   Number type: Float64
#   Built: true
# , diagnostic = Dict{String, Any}("Maximum objective value" => 4519.959774542214, "Optimised policy economic vector" => [0.039, 0.1827099433350894, 0.2063080450014098, 0.23200803504588963, 0.25938247231660155, 0.28827498289976683, 0.32184795387561715, 0.3559584010951067, 0.3886312999803645, 0.4300785524865985  …  0.2503838310990707, 0.24596175661275865, 0.2503364509992104, 0.2419892375150015, 0.22484663864405519, 0.21733782786396247, 0.19279578306066145, 0.1426895517899836, 0.01370137484998489, 0.0], "Convergence result" => :FTOL_REACHED))
#  47.402101 seconds (171.15 M allocations: 7.188 GiB, 1.88% gc time, 0.98% compilation time)

# %% [markdown]
# Note that in this optimised version, emissions and temperature are lower than in the baseline DICE model.

# %%
explore(m_opt)
# Out:
# [24428:0807/105917.853:ERROR:cache_util_win.cc(20)] Unable to move the cache: Zugriff verweigert (0x5)
# [24428:0807/105917.853:ERROR:cache_util_win.cc(20)] Unable to move the cache: Zugriff verweigert (0x5)
# [24428:0807/105917.873:ERROR:disk_cache.cc(205)] Unable to create cache
# [24428:0807/105917.873:ERROR:gpu_disk_cache.cc(673)] Gpu Cache Creation failed: -2
# [24428:0807/105917.873:ERROR:disk_cache.cc(205)] Unable to create cache
# [24428:0807/105917.873:ERROR:gpu_disk_cache.cc(673)] Gpu Cache Creation failed: -2
# Electron.Window(Application(Base.PipeEndpoint(Base.Libc.WindowsRawSocket(0x00000000000009d0) open, 0 bytes waiting), Process(setenv(`'C:\Users\marai\.julia\artifacts\397a0a9fb9e18e9c02b63a015adeadcaf37ff245\electron.exe' 'C:\Users\marai\.julia\packages\Electron\LXyZ0\src\main.js' '\\.\pipe\jlel-52d6aefe549b11ef36a20d644ec32e3f' '\\.\pipe\jlel-sn-52d72430549b11ef20c3dd9508c830c9' Oh14uie08fLGqMXxZ2sCZRzZHmK2khlaAKukgOw7HEQJjjG/kcOAWVLawnCvk23u8yKYH8N0sy39/9gSk+Vbe/qOYdPgrPO2xzlre/6ZnU+3tuWngjvbehjMSEkcVo3ltgdkXsbvvaTbty1c3oKMzMR9qlUIHkYY7lO1AImfJCc=`,["WINDIR=C:\\WINDOWS", "PATH=C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program Files (x86)\\Common Files\\Adobe\\AGL;C:\\Program Files\\Git\\cmd;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program Files (x86)\\Common Files\\Adobe\\AGL;C:\\Program Files\\Git\\cmd;C:\\Users\\marai\\AppData\\Local\\Programs\\Quarto\\bin;C:\\Users\\marai\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\marai\\AppData\\Local\\Turbo\\Cmd\\;C:\\ProgramData\\marai\\GitHubDesktop\\bin;C:\\Users\\marai\\AppData\\Local\\Programs\\Microsoft VS Code\\bin", "USERDOMAIN_ROAMINGPROFILE=LAPTOP-1S000V3T", "VSCODE_CODE_CACHE_PATH=C:\\Users\\marai\\AppData\\Roaming\\Code\\CachedData\\b1c0a14de1414fcdaa400695b4db1c0799bc3124", "LOCALAPPDATA=C:\\Users\\marai\\AppData\\Local", "HOMEPATH=\\Users\\marai", "VSCODE_NLS_CONFIG={\"userLocale\":\"en-us\",\"osLocale\":\"de-de\",\"resolvedLanguage\":\"en\",\"defaultMessagesFile\":\"C:\\\\Users\\\\marai\\\\AppData\\\\Local\\\\Programs\\\\Microsoft VS Code\\\\resources\\\\app\\\\out\\\\nls.messages.json\",\"locale\":\"en\",\"availableLanguages\":{}}", "PROCESSOR_IDENTIFIER=AMD64 Family 23 Model 24 Stepping 1, AuthenticAMD", "NUMBER_OF_PROCESSORS=8", "VSCODE_PID=3764"  …  "FPS_BROWSER_USER_PROFILE_STRING=Default", "PROCESSOR_LEVEL=23", "SYSTEMDRIVE=C:", "FPS_BROWSER_APP_PROFILE_STRING=Internet Explorer", "EFC_25888=1", "PROGRAMW6432=C:\\Program Files", "TEMP=C:\\Users\\marai\\AppData\\Local\\Temp", "HOMEDRIVE=C:", "OPENBLAS_MAIN_FREE=1", "PROCESSOR_ARCHITECTURE=AMD64"]), ProcessRunning), [1 window]), 1, true, Channel{Any}(128))

# %% [markdown]
# Again, you can change parameters, or components, and re-run the optimisation to see how the model behaves under different conditions.
